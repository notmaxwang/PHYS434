# %%
#Problem 1

#Probability of rolling two ones P(1,1)
# = 1/36

#Probability of rolling a combination of 7 P(sum = 7)
# possibilties are (1,6) (2,5) (3,4) (4,3) (5,2) (6,1)
# = 6/36 = 1/6

#Ratio (1/36) / (1/6) = 1/6

#Problem 2

#By counting
#Rolling a 2: 1 / 36
#Rolling a 3: 2 / 36
#Rolling a 4: 3 / 36
#Rolling a 5: 4 / 36
#Rolling a 6: 5 / 36
#Rolling a 7: 6 / 36
#Rolling a 8: 5 / 36
#Rolling a 9: 4 / 36
#Rolling a 10: 3 / 36
#Rolling a 11: 2 / 36
#Rolling a 12 : 1 / 36

#By program
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import statistics


#Problem 3
#mean of distribution ( 36 / 11 ) / 36
#variance 
#v = statistics.variance(dist)

plt.rcParams["figure.figsize"] = (15,10)
x = np.linspace(stats.norm.ppf(0.01, loc = 1/6), stats.norm.ppf(0.99, loc = 1/6), 2)
plt.plot(x, stats.norm.pdf(x))

# %%
#Problem 4
x = np.linspace(stats.norm.ppf(0.01, loc = 1/36), stats.norm.ppf(0.99, loc = 1/36), 10)
plt.plot(x, stats.norm.pdf(x))

# %%
# This is a gaussian distribution with the averae of ten dice, as it has a normalized distribution on both sides.

#Problem 5
#[x1, x2, x3, ...] random sample of Gaussian distribution

#Sum is xsum = x1+x2+x3+...+xi
#mean is xsum / n
#Variance n * sum(x1-mean + x2-mean +...)^2
#Which is a normal distribution

#Average is also a normal distribution with mean being xsum/n and variance being sum(x1-mean + x2-mean +...)^2
